# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("highest_earning_players.csv")
df1.head()
# Out:
#    PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen       dupreeh          dk     1822989.41
# 1      3679   Andreas   Højsleth         Xyp9x          dk     1799288.57
# 2      3885   Nicolai     Reedtz        dev1ce          dk     1787489.88
# 3      3672     Lukas  Rossander        gla1ve          dk     1652350.75
# 4     17800      Emil       Reif        Magisk          dk     1416448.64
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 1  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
df1.shape
# Out:
# (1000, 8)

# %%
df1.groupby('CurrentHandle')['CurrentHandle'].agg('count')
# Out:
# CurrentHandle
# 007x        1
# 067QAQ      1
# 0nuqtive    1
# 139         1
# 369         1
#            ..
# 月色          1
# 柠栀          1
# 行星          1
# 轻雨          1
# 阿可          1
# Name: CurrentHandle, Length: 990, dtype: int64

# %%
df2 = df1.drop(['CurrentHandle', 'CountryCode'], axis='columns')
df2.head()
# Out:
#    PlayerId NameFirst   NameLast  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen     1822989.41
# 1      3679   Andreas   Højsleth     1799288.57
# 2      3885   Nicolai     Reedtz     1787489.88
# 3      3672     Lukas  Rossander     1652350.75
# 4     17800      Emil       Reif     1416448.64
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 1  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
df2.isnull().sum()
# Out:
# PlayerId         0
# NameFirst        0
# NameLast         0
# TotalUSDPrize    0
# Game             0
# Genre            0
# dtype: int64

# %%
df3 = df2.drop(df2[(df2['NameFirst']=='-') | (df2['NameLast']=='-')].index)
print(df3.head())
# Out:
#    PlayerId NameFirst   NameLast  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen     1822989.41
# 1      3679   Andreas   Højsleth     1799288.57
# 2      3885   Nicolai     Reedtz     1787489.88
# 3      3672     Lukas  Rossander     1652350.75
# 4     17800      Emil       Reif     1416448.64
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 1  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
required_item = '-'
if required_item not in df3['NameFirst'].values:
    print("Dropped")
else:
    print("Try again")
# Out:
# Dropped

# %%
rgx = r'[^a-zA-Z]'
df4 = df2.drop(df2[df2['NameFirst'].str.contains(rgx, regex=True) | (df2['NameLast'].str.contains(rgx, regex=True))].index)
df4.head()
# Out:
#    PlayerId NameFirst   NameLast  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen     1822989.41
# 2      3885   Nicolai     Reedtz     1787489.88
# 3      3672     Lukas  Rossander     1652350.75
# 4     17800      Emil       Reif     1416448.64
# 5     16800     Jakey        Yip     1087340.00
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter
# 5  Counter-Strike: Global Offensive  First-Person Shooter

# %%
required_item = r'[^a-zA-Z]'
if required_item not in df3['NameFirst'].values:
    print("Dropped")
else:
    print("Try again")
# Out:
# Dropped

# %%
df4['Game'].unique()
# Out:
# array(['Counter-Strike: Global Offensive', 'Dota 2', 'League of Legends',
#        'Fortnite', 'Overwatch', 'Starcraft II', 'Heroes of the Storm',
#        'PUBG', 'Arena of Valor', 'Hearthstone'], dtype=object)

# %%
df4.to_csv('Cleaned_earning.csv', index=False)

# %%
df1.head()
# Out:
#    PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen       dupreeh          dk     1822989.41
# 1      3679   Andreas   Højsleth         Xyp9x          dk     1799288.57
# 2      3885   Nicolai     Reedtz        dev1ce          dk     1787489.88
# 3      3672     Lukas  Rossander        gla1ve          dk     1652350.75
# 4     17800      Emil       Reif        Magisk          dk     1416448.64
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 1  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
# df4.reset_index(drop=True, inplace=True)
df_backup = df1.copy()
dropped = df_backup[df_backup.index.isin(df4.index)]
dropped = dropped.drop(df4.columns, axis=1)
df5 = pd.concat([df4, dropped], axis=1)
df5.head()
# Out:
#    PlayerId NameFirst   NameLast  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen     1822989.41
# 1      3885   Nicolai     Reedtz     1787489.88
# 2      3672     Lukas  Rossander     1652350.75
# 3     17800      Emil       Reif     1416448.64
# 4     16800     Jakey        Yip     1087340.00
#
#                                Game                 Genre CurrentHandle  \
# 0  Counter-Strike: Global Offensive  First-Person Shooter       dupreeh
# 1  Counter-Strike: Global Offensive  First-Person Shooter         Xyp9x
# 2  Counter-Strike: Global Offensive  First-Person Shooter        dev1ce
# 3  Counter-Strike: Global Offensive  First-Person Shooter        gla1ve
# 4  Counter-Strike: Global Offensive  First-Person Shooter        Magisk
#
#   CountryCode
# 0          dk
# 1          dk
# 2          dk
# 3          dk
# 4          dk

# %%
df5.to_csv('Column_Cleaned_earning.csv', index=False)

# %%
rgx = r'[^a-zA-Z]'
df6 = df5.drop(df5[df5['CurrentHandle'].str.contains(rgx, regex=True)].index)
df6.head()
# Out:
#    PlayerId NameFirst   NameLast  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen     1822989.41
# 4     16800     Jakey        Yip     1087340.00
# 6      2455   Gabriel     Toledo     1059938.92
# 7     12182   Marcelo      David     1021901.46
# 8     10629     Keith   Markovic      982765.66
#
#                                Game                 Genre CurrentHandle  \
# 0  Counter-Strike: Global Offensive  First-Person Shooter       dupreeh
# 4  Counter-Strike: Global Offensive  First-Person Shooter        Magisk
# 6  Counter-Strike: Global Offensive  First-Person Shooter          TACO
# 7  Counter-Strike: Global Offensive  First-Person Shooter           fer
# 8  Counter-Strike: Global Offensive  First-Person Shooter        FalleN
#
#   CountryCode
# 0          dk
# 4          dk
# 6          br
# 7          br
# 8          br

# %%
df6.to_csv('New_Cleaned_earning.csv', index=False)
